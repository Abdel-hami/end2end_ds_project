# %%
MLFLOW_TRACKING_URI = '../models/mlruns'
MLFLOW_EXPERIMENT_NAME = "skills_jobs_stackoverflow"

# %%
import mlflow
from mlflow.tracking import MlflowClient
import pandas as pd

# %%
#initialize client
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client = MlflowClient()

# %%
# get experiment
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
exp
# Out:
# <Experiment: artifact_location='file:///C:/Users/user/Desktop/end2end_ds_project/notebooks/../models/mlruns/377147707337886246', creation_time=1766153229823, experiment_id='377147707337886246', last_update_time=1766153229823, lifecycle_stage='active', name='skills_jobs_stackoverflow', tags={}>

# %%
# get all runs
runs = mlflow.search_runs([exp.experiment_id])
runs
# Out:
#                              run_id       experiment_id    status  \
# 0  493ac2925d734815b116ac8b5c5f4be9  377147707337886246  FINISHED
# 1  b5e45476d4674ca4b7f189781ae62707  377147707337886246  FINISHED
# 2  0c40c1b3171b449e90222c4b38d216e3  377147707337886246  FINISHED
# 3  2d54b400b3e54ca69892702b1b6cb425  377147707337886246  FINISHED
# 4  8863c5d543e94fe683de883a94c1fca3  377147707337886246  FINISHED
# 5  303be484e47d4691b09d0f41a6ac791e  377147707337886246  FINISHED
# 6  1b24141f461f4d84899a3b20ead38e3b  377147707337886246  FINISHED
# 7  73ee1312f7a94a37830429596642ab4f  377147707337886246  FINISHED
# 8  4ffbe1cd405942e8a23f2662b03e6f84  377147707337886246    FAILED
#
#                                         artifact_uri  \
# 0  file:///C:/Users/user/Desktop/end2end_ds_proje...
# 1  file:///C:/Users/user/Desktop/end2end_ds_proje...
# 2  file:///C:/Users/user/Desktop/end2end_ds_proje...
# 3  file:///C:/Users/user/Desktop/end2end_ds_proje...
# 4  file:///C:/Users/user/Desktop/end2end_ds_proje...
# 5  file:///C:/Users/user/Desktop/end2end_ds_proje...
# 6  file:///C:/Users/user/Desktop/end2end_ds_proje...
# 7  file:///C:/Users/user/Desktop/end2end_ds_proje...
# 8  file:///C:/Users/user/Desktop/end2end_ds_proje...
#
#                         start_time                         end_time  \
# 0 2025-12-25 13:40:05.735000+00:00 2025-12-25 13:40:06.842000+00:00
# 1 2025-12-25 13:37:23.378000+00:00 2025-12-25 13:37:24.329000+00:00
# 2 2025-12-23 09:19:44.883000+00:00 2025-12-23 09:19:46.018000+00:00
# 3 2025-12-23 09:17:02.231000+00:00 2025-12-23 09:17:03.747000+00:00
# 4 2025-12-22 17:15:00.313000+00:00 2025-12-22 17:15:01.604000+00:00
# 5 2025-12-22 16:51:00.243000+00:00 2025-12-22 16:51:01.713000+00:00
# 6 2025-12-19 17:06:46.935000+00:00 2025-12-19 17:06:48.710000+00:00
# 7 2025-12-19 14:15:14.446000+00:00 2025-12-19 14:15:14.762000+00:00
# 8 2025-12-19 14:09:05.874000+00:00 2025-12-19 14:09:05.965000+00:00
#
#    metrics.f1_score  metrics.recall_score  metrics.accuracy_score  \
# 0         74.293125             63.884375               93.795000
# 1         73.537500             62.121250               93.699375
# 2         74.293125             63.884375               93.795000
# 3         73.537500             62.121250               93.699375
# 4         74.293125             63.884375               93.795000
# 5         73.537500             62.121250               93.699375
# 6         73.537500             62.121250               93.699375
# 7         35.813125             27.813125               88.191250
# 8               NaN                   NaN                     NaN
#
#    metrics.precision_score tags.mlflow.source.type tags.mlflow.user  \
# 0                89.803750                   LOCAL             user
# 1                90.983125                   LOCAL             user
# 2                89.803750                   LOCAL             user
# 3                90.983125                   LOCAL             user
# 4                89.803750                   LOCAL             user
# 5                90.983125                   LOCAL             user
# 6                90.983125                   LOCAL             user
# 7                58.871875                   LOCAL             user
# 8                      NaN                   LOCAL             user
#
#                     tags.mlflow.runName  \
# 0   Random Forest: with PCA - KernelPca
# 1       Random Forest: with PCA - Basic
# 2   Random Forest: with PCA - KernelPca
# 3       Random Forest: with PCA - Basic
# 4   Random Forest: with PCA - KernelPca
# 5       Random Forest: with PCA - Basic
# 6       Random Forest: with PCA - Basic
# 7  Baseline model: Logistic Regression
# 8  Baseline model: Logistic Regression
#
#                              tags.mlflow.source.name
# 0  C:\Users\user\AppData\Local\Programs\Python\Py...
# 1  C:\Users\user\AppData\Local\Programs\Python\Py...
# 2  C:\Users\user\AppData\Local\Programs\Python\Py...
# 3  C:\Users\user\AppData\Local\Programs\Python\Py...
# 4  C:\Users\user\AppData\Local\Programs\Python\Py...
# 5  C:\Users\user\AppData\Local\Programs\Python\Py...
# 6  C:\Users\user\AppData\Local\Programs\Python\Py...
# 7  C:\Users\user\AppData\Local\Programs\Python\Py...
# 8  C:\Users\user\AppData\Local\Programs\Python\Py...
